# %% [markdown]
# # This is demo about how to use facebooks recently released Detr: by using their pretrained model in pytorch
#
# * Easiest way to implement object detection without getting into too many details
#
# *   link paper : https://arxiv.org/abs/2005.12872
# *   blog link : https://ai.facebook.com/research/publications/end-to-end-object-detection-with-transformers
#
# **if you want to see the original source you can always checkout their github repository [here](https://github.com/facebookresearch/detr) and Demo version [here](https://colab.research.google.com/github/facebookresearch/detr/blob/colab/notebooks/detr_demo.ipynb). Most of the codes here is borrowed from the demo**

# %%
from PIL import Image, ImageDraw, ImageFont
import requests
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'retina'

import torch
from torch import nn
from torchvision.models import resnet50
import torchvision.transforms as T
torch.set_grad_enabled(False);

# %% [markdown]
# # Downloading Pretrained model

# %%
model = torch.hub.load('facebookresearch/detr', 'detr_resnet50', pretrained=True)
# Out:
# Downloading: "https://github.com/facebookresearch/detr/archive/master.zip" to /root/.cache/torch/hub/master.zip
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# ...
# Downloading: "https://dl.fbaipublicfiles.com/detr/detr-r50-e632da11.pth" to /root/.cache/torch/hub/checkpoints/detr-r50-e632da11.pth
# ...

# %% [markdown]
# Adding helper functions to normalise images

# %%
# standard PyTorch mean-std input image normalization
transform = T.Compose([
    T.ToTensor(),
    T.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# for output bounding box post-processing
def box_cxcywh_to_xyxy(x):
    x_c, y_c, w, h = x.unbind(1)
    b = [(x_c - 0.5 * w), (y_c - 0.5 * h),
         (x_c + 0.5 * w), (y_c + 0.5 * h)]
    return torch.stack(b, dim=1)

def rescale_bboxes(out_bbox, size):
    img_w, img_h = size
    b = box_cxcywh_to_xyxy(out_bbox)
    b = b * torch.tensor([img_w, img_h, img_w, img_h], dtype=torch.float32)
    return b

# %%
# COCO classes
CLASSES = [
    'N/A', 'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus',
    'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'N/A',
    'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse',
    'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'N/A', 'backpack',
    'umbrella', 'N/A', 'N/A', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis',
    'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove',
    'skateboard', 'surfboard', 'tennis racket', 'bottle', 'N/A', 'wine glass',
    'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich',
    'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake',
    'chair', 'couch', 'potted plant', 'bed', 'N/A', 'dining table', 'N/A',
    'N/A', 'toilet', 'N/A', 'tv', 'laptop', 'mouse', 'remote', 'keyboard',
    'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'N/A',
    'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier',
    'toothbrush'
]

# colors for visualization
COLORS = [[0.000, 0.447, 0.741], [0.850, 0.325, 0.098], [0.929, 0.694, 0.125],
          [0.494, 0.184, 0.556], [0.466, 0.674, 0.188], [0.301, 0.745, 0.933]]

# %%
link = "http://images.cocodataset.org/val2017/000000039769.jpg"

img = requests.get(link, stream=True).raw
img = Image.open(img).resize((800, 600))
img = img.convert('RGB')

# %%
im = transform(img).unsqueeze(0)
with torch.no_grad():
  outputs = model(im)

# %%
pic = img.copy()
drw = ImageDraw.Draw(pic)
bboxes = outputs['pred_boxes'][0]
logits = outputs['pred_logits']

for boxes, logit, c in zip(bboxes, logits[0], COLORS*100):
  cls = logit.argmax()
  if cls >= len(CLASSES):
    continue
  label = CLASSES[cls]
  pred = logit.softmax(-1).max(-1).values
  box = boxes * torch.Tensor([800, 600, 800, 600])
  x, y, w, h = box
  x0, x1 = x-w//2, x+w//2
  y0, y1 = y-h//2, y+h//2
  drw.rectangle([x0, y0, x1, y1], outline="yellow", width=5)
  drw.text((x, y), label +"(" + str(pred)+ ")", color=c)

# %%
pic
# Out:
# <PIL.Image.Image image mode=RGB size=800x600 at 0x7F16B90C10B8>
